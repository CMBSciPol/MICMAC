# %% [markdown]
# # Test MH harmonic

# %%
import os, sys, time
import argparse
from collections import namedtuple
import numpy as np
import matplotlib.pyplot as plt
import scipy
import healpy as hp
import astropy.io.fits as fits
import camb
import jax
import jax.numpy as jnp
import jax.scipy as jsp
import jax_healpy as jhp
import jax.random as random
import toml
import numpyro
from functools import partial
import micmac
from micmac import *
from fgbuster.observation_helpers import *

# %%
from jax import config
current_path = os.path.abspath('')
sys.path.append(current_path)

config.update("jax_enable_x64", True)

# %%
path_toml_file = current_path+'/Harm_fullsky_v1a.toml'
path_toml_file = current_path+'/Harm_fullsky_v1b.toml'
path_home_test_playground = os.path.dirname(current_path) + '/'

# %%
MICMAC_obj = create_Harmonic_MICMAC_sampler_from_toml_file(path_toml_file)

# %%
seed_realization_input = MICMAC_obj.seed

# %%
fgs_model_ = 'd0s0'
instr_name = MICMAC_obj.instrument_name #'SO_SAT'

path_Fisher = path_home_test_playground + f'Fisher_matrix_{MICMAC_obj.instrument_name}_EB_model_{fgs_model_}_noise_True_seed_42_lmin2_lmax128.txt'
try :
    Fisher_matrix = np.loadtxt(path_Fisher)
except:
    print("Fisher matrix not found !", flush=True)
    Fisher_matrix = np.loadtxt(path_home_test_playground + f'Fisher_matrix_{MICMAC_obj.instrument_name}_EB_model_d0s0_noise_True_seed_42_lmin2_lmax128.txt')

# %%
instrument = get_instrument(instr_name)

# %%
np.random.seed(seed_realization_input)
freq_maps_fgs_noised = get_observation(instrument, fgs_model_, nside=MICMAC_obj.nside, noise=True)[:, 1:, :]   # keep only Q and U
np.random.seed(seed_realization_input)
freq_maps_fgs_denoised = get_observation(instrument, fgs_model_, nside=MICMAC_obj.nside, noise=False)[:, 1:, :]   # keep only Q and U

noise_map = freq_maps_fgs_noised - freq_maps_fgs_denoised
 

freq_maps_fgs = freq_maps_fgs_denoised + noise_map
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
# Mixing matrix initialization
init_mixing_matrix_obj = micmac.InitMixingMatrix(np.array(instrument['frequency']), MICMAC_obj.n_components, pos_special_freqs=[0,-1])

init_params = init_mixing_matrix_obj.init_params()

mixing_matrix_obj = micmac.MixingMatrix(instrument['frequency'], MICMAC_obj.n_components, init_params, pos_special_freqs=[0,-1])
mixing_matrix_sampled = mixing_matrix_obj.get_B()

# %%
# frequency_inv_noise_cell = get_true_Cl_noise(instrument['depth_p'], MICMAC_obj.lmax)

# MICMAC_obj.freq_noise_c_ell = frequency_inv_noise_cell

# %%
covariance_matrix = np.linalg.inv(Fisher_matrix)

MICMAC_obj.covariance_step_size_B_f = covariance_matrix[:-1, :-1]
MICMAC_obj.step_size_r = np.sqrt(covariance_matrix[-1, -1])

# %%
input_freq_maps, input_cmb_maps, theoretical_red_cov_r0_total, theoretical_red_cov_r1_tensor = MICMAC_obj.generate_input_freq_maps_from_fgs(freq_maps_fgs, return_only_freq_maps=False)
# Out:
# Calculating spectra from CAMB !
# Calculating spectra from CAMB !

# %%
theoretical_r0_total = get_c_ells_from_red_covariance_matrix(theoretical_red_cov_r0_total)
theoretical_r1_tensor = get_c_ells_from_red_covariance_matrix(theoretical_red_cov_r1_tensor)

c_ell_approx = np.zeros((3,MICMAC_obj.lmax+1))
c_ell_approx[0,MICMAC_obj.lmin:] = theoretical_r0_total[0,:]
c_ell_approx[1,MICMAC_obj.lmin:] = theoretical_r0_total[1,:]

red_cov_approx_matrix = get_reduced_matrix_from_c_ell_jax(c_ell_approx)[MICMAC_obj.lmin:]

# %%
len_pos_special_freqs = len(MICMAC_obj.pos_special_freqs)

# %% [markdown]
# ## Starting MH

# %%
minimum_std_Fisher_diag = jnp.diag(scipy.linalg.sqrtm(jnp.linalg.inv(Fisher_matrix)))
sigma_gap = 20
# sigma_gap = 2000

dimension_free_param_B_f = 2*(MICMAC_obj.n_frequencies-len_pos_special_freqs)

# %%
np.random.seed(MICMAC_obj.seed)
first_guess = jnp.zeros(dimension_free_param_B_f)
first_guess = first_guess.at[MICMAC_obj.indexes_free_Bf].set(
    init_params.ravel(order='F')[MICMAC_obj.indexes_free_Bf] + minimum_std_Fisher_diag[:-1]*np.random.uniform(low=-sigma_gap,high=sigma_gap, size=(dimension_free_param_B_f)))
init_params_mixing_matrix = first_guess.reshape((MICMAC_obj.n_frequencies-len_pos_special_freqs),2,order='F')

first_guess_r = 1e-5

# %%
init_params_mixing_matrix
# Out:
# Array([[0.33797229, 0.00920297],
#        [0.0304834 , 0.05125183],
#        [0.01039423, 0.12886883],
#        [0.00349386, 0.44103497]], dtype=float64)

# %%
MICMAC_obj.number_iterations_sampling = 1000

# %%
jnp.diag(sp.linalg.sqrtm(covariance_matrix))
# Out:
# Array([1.22719235e-04, 4.72984090e-05, 4.44084763e-05, 5.23546882e-05,
#        4.28340683e-05, 1.62270766e-05, 1.52905384e-05, 1.82529746e-05,
#        5.55036342e-04], dtype=float64)

# %%
# perform_harmonic_MH(MICMAC_obj, input_freq_maps, c_ell_approx, init_params_mixing_matrix, initial_guess_r=first_guess_r,
#                                     covariance_B_f_r=covariance_matrix, theoretical_r0_total=theoretical_r0_total, theoretical_r1_tensor=theoretical_r1_tensor)

MICMAC_obj.perform_harmonic_MH(input_freq_maps, c_ell_approx, init_params_mixing_matrix, initial_guess_r=first_guess_r,
                                    covariance_B_f_r=covariance_matrix, theoretical_r0_total=theoretical_r0_total, theoretical_r1_tensor=theoretical_r1_tensor)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       1 # perform_harmonic_MH(MICMAC_obj, input_freq_maps, c_ell_approx, init_params_mixing_matrix, initial_guess_r=first_guess_r,
#       2 #                                     covariance_B_f_r=covariance_matrix, theoretical_r0_total=theoretical_r0_total, theoretical_r1_tensor=theoretical_r1_tensor)
# ----> 4 MICMAC_obj.perform_harmonic_MH(input_freq_maps, c_ell_approx, init_params_mixing_matrix, initial_guess_r=first_guess_r,
#       5                                     covariance_B_f_r=covariance_matrix, theoretical_r0_total=theoretical_r0_total, theoretical_r1_tensor=theoretical_r1_tensor)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/micmac/Harmonic_Likelihood_sampling.py:422, in Harmonic_MICMAC_Sampler.perform_harmonic_MH(self, input_freq_maps, c_ell_approx, init_params_mixing_matrix, theoretical_r0_total, theoretical_r1_tensor, initial_guess_r, covariance_B_f_r)
#     420 ## Initial guesses
#     421 initial_eta = jnp.zeros((self.nstokes,self.n_pix))
# --> 422 params_mixing_matrix_init_sample = jnp.copy(init_params_mixing_matrix).reshape(
#     423                                     ((self.n_frequencies-len_pos_special_freqs),self.number_correlations-1), order='F')
#     425 ## CMB covariance preparation in the format [lmax,nstokes,nstokes]
#     426 red_cov_approx_matrix = get_reduced_matrix_from_c_ell_jax(c_ell_approx)[self.lmin:,...]
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/numpy/array_methods.py:146, in _reshape(a, order, *args)
#     144 elif order == "F":
#     145   dims = list(range(a.ndim)[::-1])
# --> 146   return lax.reshape(a, newshape[::-1], dims).T
#     147 elif order == "A":
#     148   raise NotImplementedError("np.reshape order=A is not implemented.")
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/lax/lax.py:864, in reshape(operand, new_sizes, dimensions)
#     861 else:
#     862   dyn_shape, static_new_sizes = _extract_tracers_dyn_shape(new_sizes)
# --> 864   return reshape_p.bind(
#     865     operand, *dyn_shape, new_sizes=tuple(static_new_sizes),
#     866     dimensions=None if dims is None or same_dims else dims)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/core.py:386, in Primitive.bind(self, *args, **params)
#     383 def bind(self, *args, **params):
#     384   assert (not config.jax_enable_checks or
#     385           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 386   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/core.py:389, in Primitive.bind_with_trace(self, trace, args, params)
#     388 def bind_with_trace(self, trace, args, params):
# --> 389   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     390   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/core.py:821, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     820 def process_primitive(self, primitive, tracers, params):
# --> 821   return primitive.impl(*tracers, **params)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/dispatch.py:120, in apply_primitive(prim, *args, **params)
#     118   in_avals, in_shardings = util.unzip2([_arg_spec(a) for a in args])
#     119   in_tree = tree_util.tree_structure(args)
# --> 120   compiled_fun = xla_primitive_callable(
#     121       prim, in_avals, in_tree, OrigShardings(in_shardings), **params)
#     122 except pxla.DeviceAssignmentMismatchError as e:
#     123   fails, = e.args
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/util.py:263, in cache.<locals>.wrap.<locals>.wrapper(*args, **kwargs)
#     261   return f(*args, **kwargs)
#     262 else:
# --> 263   return cached(config._trace_context(), *args, **kwargs)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/util.py:256, in cache.<locals>.wrap.<locals>.cached(_, *args, **kwargs)
#     254 @functools.lru_cache(max_size)
#     255 def cached(_, *args, **kwargs):
# --> 256   return f(*args, **kwargs)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/dispatch.py:149, in xla_primitive_callable(prim, in_avals, in_tree, orig_in_shardings, **params)
#     147 wrapped_fun = lu.wrap_init(prim_fun)
#     148 flat_fun, out_tree = api_util.flatten_fun_nokwargs(wrapped_fun, in_tree)
# --> 149 computation = sharded_lowering(
#     150     flat_fun, prim.name, donated_invars, keep_unused=False,
#     151     inline=True, in_avals=in_avals, in_shardings=orig_in_shardings.shardings,
#     152     lowering_platform=None)
#     153 compiled = computation.compile()
#     154 if xla_extension_version >= 192:
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/dispatch.py:179, in sharded_lowering(fun, name, donated_invars, keep_unused, inline, in_avals, in_shardings, lowering_platform)
#     174 in_shardings_unspec = [UNSPECIFIED if i is None else i for i in in_shardings]
#     176 # Pass in a singleton `UNSPECIFIED` for out_shardings because we don't know
#     177 # the number of output avals at this stage. lower_sharding_computation will
#     178 # apply it to all out_avals.
# --> 179 return pxla.lower_sharding_computation(
#     180     fun, 'jit', name, in_shardings_unspec, UNSPECIFIED, donated_invars,
#     181     in_avals, keep_unused=keep_unused, inline=inline,
#     182     devices_from_context=None, lowering_platform=lowering_platform)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:1978, in lower_sharding_computation(fun_or_jaxpr, api_name, fun_name, in_shardings, out_shardings, donated_invars, global_in_avals, keep_unused, inline, devices_from_context, lowering_platform, override_lowering_rules)
#    1972 # 1. Trace to jaxpr and preprocess/verify it
#    1973 auto_spmd_lowering = (
#    1974     check_if_any_auto(in_shardings) if is_unspecified(out_shardings) else
#    1975     check_if_any_auto(it.chain.from_iterable([in_shardings, out_shardings])))  # type: ignore
#    1977 (closed_jaxpr, global_in_avals, global_out_avals, donated_invars,
# -> 1978  kept_var_idx, name_stack) = _trace_to_jaxpr_and_dce(
#    1979     fun_or_jaxpr, global_in_avals, api_name, fun_name, keep_unused,
#    1980     donated_invars, auto_spmd_lowering)
#    1981 jaxpr = closed_jaxpr.jaxpr
#    1982 in_shardings = tuple(s for i, s in enumerate(in_shardings) if i in kept_var_idx)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:1677, in cache_wrap.<locals>.wrapped(f, *args, **kwargs)
#    1675 def wrapped(f, *args, **kwargs):
#    1676   if isinstance(f, lu.WrappedFun):
# -> 1677     return _wrapped_with_lu_cache(f, *args, **kwargs)
#    1678   else:
#    1679     return _wrapped_with_weakref_lru_cache(f, *args, **kwargs)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/linear_util.py:348, in cache.<locals>.memoized_fun(fun, *args)
#     346   fun.populate_stores(stores)
#     347 else:
# --> 348   ans = call(fun, *args)
#     349   cache[key] = (ans, fun.stores)
#     351 return ans
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:1702, in _trace_to_jaxpr_and_dce(fun_or_jaxpr, global_in_avals, api_name, fun_name, keep_unused, donated_invars, auto_spmd_lowering)
#    1698 if isinstance(fun_or_jaxpr, lu.WrappedFun):
#    1699   with dispatch.log_elapsed_time(
#    1700       "Finished tracing + transforming {fun_name} in {elapsed_time} sec",
#    1701       fun_name=str(name_stack), event=dispatch.JAXPR_TRACE_EVENT):
# -> 1702     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_final(
#    1703         fun_or_jaxpr, global_in_avals)
#    1704 else:
#    1705   assert isinstance(fun_or_jaxpr, core.ClosedJaxpr)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py:2281, in trace_to_jaxpr_final(fun, in_avals, debug_info, keep_inputs)
#    2279   main.jaxpr_stack = ()  # type: ignore
#    2280   with core.new_sublevel():
# -> 2281     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    2282       fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2283   del fun, main
#    2284 return jaxpr, out_avals, consts
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py:2225, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2223 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2224 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2225 ans = fun.call_wrapped(*in_tracers_)
#    2226 out_tracers = map(trace.full_raise, ans)
#    2227 jaxpr, consts = frame.to_jaxpr(out_tracers)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/linear_util.py:190, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     187 gen = gen_static_args = out_store = None
#     189 try:
# --> 190   ans = self.f(*args, **dict(self.params, **kwargs))
#     191 except:
#     192   # Some transformations yield from inside context managers, so we have to
#     193   # interrupt them before reraising the exception. Otherwise they will only
#     194   # get garbage-collected at some later time, running their cleanup tasks
#     195   # only after this exception is handled, which can corrupt the global
#     196   # state.
#     197   while stack:
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/dispatch.py:141, in xla_primitive_callable.<locals>.prim_fun(*args)
#     140 def prim_fun(*args):
# --> 141   out = prim.bind(*args, **params)
#     142   if prim.multiple_results:
#     143     return out
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/core.py:386, in Primitive.bind(self, *args, **params)
#     383 def bind(self, *args, **params):
#     384   assert (not config.jax_enable_checks or
#     385           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 386   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/core.py:389, in Primitive.bind_with_trace(self, trace, args, params)
#     388 def bind_with_trace(self, trace, args, params):
# --> 389   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     390   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py:1896, in DynamicJaxprTrace.process_primitive(self, primitive, tracers, params)
#    1894 def process_primitive(self, primitive, tracers, params):
#    1895   if primitive in custom_staging_rules:
# -> 1896     return custom_staging_rules[primitive](self, *tracers, **params)
#    1897   return self.default_process_primitive(primitive, tracers, params)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/lax/lax.py:3411, in _reshape_staging_rule(trace, x, new_sizes, dimensions, *dyn)
#    3409 params = dict(new_sizes=new_sizes, dimensions=dimensions)
#    3410 if not dyn:
# -> 3411   return trace.default_process_primitive(reshape_p, (x,), params)
#    3412 av = core.DShapedArray(_merge_dyn_shape(new_sizes, dyn), x.dtype, x.weak_type)
#    3413 return _dyn_shape_staging_rule(trace, reshape_p, av, x, *dyn, **params)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py:1901, in DynamicJaxprTrace.default_process_primitive(self, primitive, tracers, params)
#    1899 def default_process_primitive(self, primitive, tracers, params):
#    1900   avals = [t.aval for t in tracers]
# -> 1901   out_avals, effects = primitive.abstract_eval(*avals, **params)
#    1902   # == serve as a "not xor" here.
#    1903   if not (isinstance(out_avals, (tuple,list)) == primitive.multiple_results):
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/core.py:422, in _effect_free_abstract_eval.<locals>.abstract_eval_(*args, **kwargs)
#     421 def abstract_eval_(*args, **kwargs):
# --> 422   return abstract_eval(*args, **kwargs), no_effects
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/lax/utils.py:60, in standard_abstract_eval(prim, shape_rule, dtype_rule, weak_type_rule, named_shape_rule, *avals, **kwargs)
#      58   return core.ConcreteArray(out.dtype, out, weak_type=weak_type)
#      59 elif least_specialized is core.ShapedArray:
# ---> 60   return core.ShapedArray(shape_rule(*avals, **kwargs),
#      61                           dtype_rule(*avals, **kwargs), weak_type=weak_type,
#      62                           named_shape=named_shape_rule(*avals, **kwargs))
#      63 elif least_specialized is core.DShapedArray:
#      64   shape = shape_rule(*avals, **kwargs)
#
# File ~/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/jax/_src/lax/lax.py:3357, in _reshape_shape_rule(operand, new_sizes, dimensions)
#    3354 if (not config.jax_dynamic_shapes and
#    3355     not math.prod(np.shape(operand)) == math.prod(new_sizes)):
#    3356   msg = 'reshape total size must be unchanged, got new_sizes {} for shape {}.'
# -> 3357   raise TypeError(msg.format(new_sizes, np.shape(operand)))
#    3358 if dimensions is not None:
#    3359   if set(dimensions) != set(range(np.ndim(operand))):
#
# TypeError: reshape total size must be unchanged, got new_sizes (2, 4) for shape (5, 4, 2).

# %%
np.repeat(init_params_mixing_matrix,3).reshape((3, init_params_mixing_matrix.shape[0], init_params_mixing_matrix.shape[1]), order='F')
# Out:
# Array([[[0.33797229, 0.01039423],
#         [0.00920297, 0.12886883],
#         [0.0304834 , 0.00349386],
#         [0.05125183, 0.44103497]],
#
#        [[0.33797229, 0.01039423],
#         [0.00920297, 0.12886883],
#         [0.0304834 , 0.00349386],
#         [0.05125183, 0.44103497]],
#
#        [[0.33797229, 0.01039423],
#         [0.00920297, 0.12886883],
#         [0.0304834 , 0.00349386],
#         [0.05125183, 0.44103497]]], dtype=float64)

# %%
np.repeat(init_params_mixing_matrix.ravel(order='F'),3).reshape((3, init_params_mixing_matrix.shape[0]*init_params_mixing_matrix.shape[1]), order='F')
# Out:
# Array([[0.33797229, 0.0304834 , 0.01039423, 0.00349386, 0.00920297,
#         0.05125183, 0.12886883, 0.44103497],
#        [0.33797229, 0.0304834 , 0.01039423, 0.00349386, 0.00920297,
#         0.05125183, 0.12886883, 0.44103497],
#        [0.33797229, 0.0304834 , 0.01039423, 0.00349386, 0.00920297,
#         0.05125183, 0.12886883, 0.44103497]], dtype=float64)

# %%
MICMAC_obj.all_samples_r.shape
# Out:
# (20000,)

# %%
MICMAC_obj.all_params_mixing_matrix_samples.shape
# Out:
# (20000, 4, 2)

# %%
list_correl = ['EE', 'BB', 'EB']

ell_arange = np.arange(red_cov_approx_matrix.shape[0]) + MICMAC_obj.lmin

frequency_Bf = np.array(instrument['frequency'][1:-1])

all_B_f_sample_synch = MICMAC_obj.all_params_mixing_matrix_samples[:,:,0]
all_B_f_sample_dust = MICMAC_obj.all_params_mixing_matrix_samples[:,:,1]

frequency_array = np.array(instrument['frequency'])


if MICMAC_obj.n_frequencies-len_pos_special_freqs < 10:
    plt.figure(figsize=(20,8))
    plt.suptitle('Mixing matrix parameters sampled vs iterations', fontsize=14)
    # plt.subplot(121)

    for i in range(MICMAC_obj.n_frequencies-len_pos_special_freqs):
        plt.subplot(201+len(frequency_Bf)*10+i)
        plt.title((f'Synch ${frequency_Bf[i]} GHz$'))
        plt.plot([0,MICMAC_obj.number_iterations_sampling], [init_params[i,0],init_params[i,0]], label='Exact value')
        plt.plot(np.arange(MICMAC_obj.number_iterations_sampling), all_B_f_sample_synch[:,i], '-.', label='Sample')
        
        n_sigma = 3
        transformed_samples = np.abs(all_B_f_sample_synch[:,i] - all_B_f_sample_synch[:,i].mean())/(all_B_f_sample_synch[:,i].std()) #< n_sigma
        cond = np.exp(transformed_samples**2/2)/(np.sqrt(2*np.pi)) < 0.9973
        mean_B_f = np.round(all_B_f_sample_synch[:,i][cond].mean(), decimals=5)
        std_B_f = np.round(all_B_f_sample_synch[:,i][cond].std(), decimals=5)

        mean_value = all_B_f_sample_synch[:,i].mean()
        plt.plot([0,MICMAC_obj.number_iterations_sampling], [mean_B_f,mean_B_f], ':', label='Samples mean 99.7%')

        # plt.yscale('log')
        # plt.xlabel('Iterations')
        if i == 0:
            plt.ylabel('Amplitude')
    plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left", prop={'size': 15}, frameon=False)
    # plt.loglog()

    # plt.figure(figsize=(20,8))
    # plt.subplot(122)
    for i in range(MICMAC_obj.n_frequencies-len_pos_special_freqs):
        plt.subplot(201+len(frequency_Bf)*10+i+len(frequency_Bf))
        # plt.subplot(201+len(frequency_Bf)*10+i)
        plt.title((f'Dust ${frequency_Bf[i]} GHz$'))
        plt.plot([0,MICMAC_obj.number_iterations_sampling], [init_params[i,1],init_params[i,1]], label='Exact value')
        plt.plot(np.arange(MICMAC_obj.number_iterations_sampling), all_B_f_sample_dust[:,i], '-.', label='Sample')

        n_sigma = 3
        transformed_samples = np.abs(all_B_f_sample_dust[:,i] - all_B_f_sample_dust[:,i].mean())/(all_B_f_sample_dust[:,i].std()) #< n_sigma
        cond = np.exp(transformed_samples**2/2)/(np.sqrt(2*np.pi)) < 0.9973
        mean_B_f = np.round(all_B_f_sample_dust[:,i][cond].mean(), decimals=5)
        std_B_f = np.round(all_B_f_sample_dust[:,i][cond].std(), decimals=5)

        mean_value = all_B_f_sample_dust[:,i].mean()
        plt.plot([0,MICMAC_obj.number_iterations_sampling], [mean_B_f,mean_B_f], ':', label='Samples mean 99.7%')
        # plt.yscale('log')
        plt.xlabel('Iterations')
        if i == 0:
            plt.ylabel('Amplitude')
    plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left", prop={'size': 15}, frameon=False)
    # plt.loglog()

    plt.show()

# %%
plt.figure(figsize=(14,4))

n_sigma = 3

all_r_samples = MICMAC_obj.all_samples_r

cond = np.abs((all_r_samples - all_r_samples.mean())/(all_r_samples.std())) < n_sigma
print(all_r_samples[cond].shape, MICMAC_obj.number_iterations_sampling)
mean_r = np.round(all_r_samples[cond].mean(), decimals=5)
std_r = np.round(all_r_samples[cond].std(), decimals=5)


plt.suptitle(f"Mean value $r = {mean_r} \pm {std_r}$ (99.7%)")

plt.subplot(121)
plt.plot(np.arange(MICMAC_obj.number_iterations_sampling), all_r_samples, label='r samples')
plt.plot([0, MICMAC_obj.number_iterations_sampling], [MICMAC_obj.r_true,MICMAC_obj.r_true], 'k:', label='r true')


plt.xlabel("Iterations")
plt.ylabel('$r$ sample')
plt.title(r'Evolution of $r$ samples')
plt.yscale('symlog')
plt.legend()
# plt.ylim(ymin=MICMAC_obj.r_true*.7, ymax=MICMAC_obj.r_true*1.3)

plt.subplot(122)
hist_values, bins_value, _ = plt.hist(all_r_samples, bins='rice', label='r samples')
plt.plot([MICMAC_obj.r_true,MICMAC_obj.r_true], [0,hist_values.max()], 'r--', label='r true')
plt.legend()
plt.show()
# Out:
# (19918,) 20000
# /Users/mag/miniconda3/envs/non_param_silver/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   fig.canvas.print_figure(bytes_io, **kw)
